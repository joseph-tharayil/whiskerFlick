# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from scipy.stats import linregress
# %matplotlib ipympl
import matplotlib
font = {'family' : 'normal',
        'weight':'normal',
        'size'   : 12}

matplotlib.rc('font', **font)
import time

# %%
from scipy import signal

sos = signal.butter(3, [1,100], 'bp', fs=10000, output='sos')

# %%
time = np.arange(0,3000,.1)

# %%
EEGs = np.load('EEGs.npy',allow_pickle=True).item()
total = np.load('total.npy')

# %%
total[:,-2]
# Out:
# array([0.00000000e+00, 2.19257066e-07, 1.44818287e-06, ...,
#        6.57682615e-07, 7.05754076e-07, 7.34494249e-07])

# %%
p = pd.read_pickle('0/pkls/eegL1_DAC.pkl')

# %%
eegOriginal = np.load('../../original/72b70ea2-4521-47f1-842c-9ae4e64d54f4/EEGs.npy',allow_pickle=True).item()
totalOriginal = np.load('../../original/72b70ea2-4521-47f1-842c-9ae4e64d54f4/total.npy')

# %%
import bluepysnap as bp

# %%
bin_edges = np.arange(0,3000,10)

# %%
spikeRates = []

for type in EEGs.keys():
    for j in range(1):
        
        
        s = bp.Simulation(str(j)+'/simulation_config.json')
        r = s.spikes['S1nonbarrel_neurons']
        
        f = bp.spike_report.FilteredSpikeReport(r,group=type)

# %%
plt.figure()
plt.plot(total[:,0])
plt.plot(total[:,-1])
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# ...

# %%
plt.figure(figsize=(10,5))



plt.subplot(1,2,1)
plt.plot(time,total[:,0]/100)
# plt.plot(time,totalOriginal/100)
plt.ylabel('Amplitude (au)')
# plt.xlim([1975,2300])
# plt.gca().set_xticklabels([])
# plt.ylim([-2e-6,2e-6])
plt.title('Total signal')
plt.xlabel('Time (ms)')

plt.subplot(1,2,2)
for layer in np.arange(2,7):
    signal = 0
    for t in EEGs.keys():
        if str(layer) in t:
            try:
                signal += EEGs[t]
            except:
                pass

    plt.plot(time,signal[:,0]/100,c='C'+str(layer))

# for layer in np.arange(2,7):
#     signal = 0
#     for t in eegOriginal.keys():
#         if str(layer) in t:
#             try:
#                 signal += eegOriginal[t]
#             except:
#                 pass

#     plt.plot(time,signal[:,0]/100,'--',c='C'+str(layer))
    
plt.legend(np.arange(2,7))
# plt.xlim([1975,2300])
# plt.ylim([-2e-6,2e-6])
plt.ylabel('Amplitude (au)')
plt.xlabel('Time (ms)')
plt.title('Contribution by layer')

plt.tight_layout()
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# ...

# %%
plt.figure()
plt.plot(time,total/100)
# plt.plot(EEGs['L2_TPC:A']+EEGs['L2_TPC:B'])
# plt.plot(EEGs['L3_TPC:A']+EEGs['L3_TPC:C'])
# plt.plot(EEGs['L4_TPC'])
# plt.plot(EEGs['L5_TPC:A']+EEGs['L5_TPC:B']+EEGs['L5_TPC:C'])
# plt.plot(EEGs['L6_TPC:A']+EEGs['L6_TPC:C'])

plt.show()

# %%
EEGs.keys()

# %%
plt.figure()
plt.plot(time,total)
exc = 0
for t in exctypes:
    exc += EEGs[t]
inh = 0
for t in inhtypes:
    inh += EEGs[t]
plt.plot(time,exc)
plt.plot(time,inh)

# %%
plt.figure()
signals = []
for layer in np.arange(2,7):
    signal = 0
    for t in exctypes:
        if str(layer) in t:
            signal += EEGs[t]
    signals.append(signal)
    plt.plot(time,signal)
plt.legend(np.arange(2,7))

# %%
plt.figure()
plt.plot(time,signals[3])

# %%
plt.figure()
plt.plot(total)
plt.plot(signals[3]+signals[4])

# %%
plt.figure()
legend = []
for t in exctypes:
    if '5' in t:
        plt.plot(EEGs[t])
        legend.append(t)
plt.legend(legend)

# %%
plt.figure()
legend = []
for t in exctypes:
    if '6' in t:
        plt.plot(EEGs[t])
        legend.append(t)
plt.legend(legend)

# %%
plt.figure()
plt.plot(total/50)
