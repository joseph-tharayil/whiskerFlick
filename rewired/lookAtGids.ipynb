# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
# %matplotlib widget

# %%
import matplotlib
font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
conn_file = '/gpfs/bbp.cscs.ch/project/proj83/scratch/home/reimann/O1_Schneider_Mizell/stage2_df__with_aff_center_xyz.h5'
conn_df = pd.read_hdf(conn_file, 'final_remapped_ids')  # IDs already mapped to O1 circuit

# %%
conn_df
# Out:
#           @source_node  @target_node  afferent_section_id  \
# 0                    0        205237                  294
# 1                    0        184409                  342
# 2                    0         23068                  115
# 3                    0        146101                  227
# 4                    0        165299                  209
# ...                ...           ...                  ...
# 55923270        210706        182496                  151
# 55923271        210706        206618                  190
# 55923272        210706        176005                  117
# 55923273        210706         41999                   79
# 55923274        210706        190008                  198
#
#           afferent_section_pos  afferent_segment_id  afferent_segment_offset  \
# 0                     0.145799                   12                 0.704636
# 1                     0.621072                    1                 8.483885
# ...

# %%
len(np.unique(conn_df['@source_node'].values))
# Out:
# 18129

# %%
rewired = conn_df[conn_df['@algorithm']=='proximal']

# %%
len(pd.unique(conn_df['@source_node']))
# Out:
# 18129
