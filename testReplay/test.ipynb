# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bluepysnap as bp
# %matplotlib widget

# %%
s = bp.Simulation('connected/simulation_config.json')
r = s.reports['voltage']
d = r['S1nonbarrel_neurons'].get()

# %%
s1 = bp.Simulation('disconnected_noise/simulation_config.json')
r1 = s1.reports['voltage']
d1 = r1['S1nonbarrel_neurons'].get()

# %%
s2 = bp.Simulation('connected_stim/simulation_config.json')
r2 = s2.reports['voltage']
d2 = r2['S1nonbarrel_neurons'].get()

# %%
s3 = bp.Simulation('disconnected_noStim/simulation_config.json')
r3 = s3.reports['voltage']
d3 = r3['S1nonbarrel_neurons'].get()

# %%
plt.figure(figsize=(6,4))
plt.subplot(1,3,1)
plt.plot(d[2775])
# plt.plot(d2[2775])
plt.title(2775)
plt.xlabel('time (ms)')
plt.ylabel('soma voltage (v)')
plt.legend(['Disconnected','Connected'])
# plt.plot(d3[2775])

plt.subplot(1,3,2)
plt.plot(d[4794])
# plt.plot(d2[4794])
plt.title(4794)
plt.xlabel('time (ms)')
plt.ylabel('soma voltage (v)')
# plt.plot(d3[4794])

plt.subplot(1,3,3)
plt.plot(d[25493])
# plt.plot(d2[25493])
plt.title(25493)
plt.xlabel('time (ms)')
plt.ylabel('soma voltage (v)')
# plt.plot(d3[25493])

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
d
# Out:
#            2775       4794       25493
# 0.0   -80.000000 -80.000000 -80.000000
# 0.1   -79.973434 -79.972801 -80.018486
# 0.2   -79.943382 -79.942131 -80.032555
# 0.3   -79.912209 -79.910065 -80.045090
# 0.4   -79.880737 -79.877464 -80.056572
# ...          ...        ...        ...
# 999.5 -74.064186 -76.241570 -62.625790
# 999.6 -74.030106 -76.210976 -62.618256
# 999.7 -73.996040 -76.180473 -62.610687
# 999.8 -73.961990 -76.150055 -62.603085
# 999.9 -73.927956 -76.119728 -62.595448
#
# [10000 rows x 3 columns]
