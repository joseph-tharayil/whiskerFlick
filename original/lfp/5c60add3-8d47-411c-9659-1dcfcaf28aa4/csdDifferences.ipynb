# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
distances_within = np.load('distances_within.npy')

# %%
distances_across_half = np.load('distances_across_evoked_scaled_0.5.npy')
distances_across_1 = np.load('distances_across_evoked_scaled_1.0.npy')
distances_across_2 = np.load('distances_across_evoked_scaled_2.0.npy')

# %%
meanDiff = np.mean(distances_within[distances_within!=0])

# %%
mean_distances_across = np.mean(distances_across_1,axis=0)/meanDiff
std_distances_across = np.std(distances_across_1,axis=0)/meanDiff

# %%
mean_distances_across += np.rot90(np.fliplr(mean_distances_across))

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.gca()
im = ax.imshow(mean_distances_across)
labels = ['iCSD','iCSD/2','iCSD/4','Sphere','Sphere/2','Sphere/4','Disk','Disk/2','Disk/4']
ax.set_xticks(np.arange(9),labels=labels)
plt.yticks(np.arange(9),labels=labels)
fig.colorbar(im,label="Earthmover distance\nNormalized to distance between trials",location='bottom')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
m
# Out:
# array([[0.        , 9.14708441, 8.46942058],
#        [9.14708441, 0.        , 9.27420171],
#        [8.46942058, 9.27420171, 0.        ]])

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.gca()
m = mean_distances_across[[0,3,5]]
m = m[:,[0,3,5]]
im = ax.imshow(m)
labels = ['iCSD','Sphere','Disk']
ax.set_xticks(np.arange(3),labels=labels)
plt.yticks(np.arange(3),labels=labels)
fig.colorbar(im,label="Earthmover distance\nNormalized to distance between trials",location='bottom')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(np.arange(len(mean_distances_across)),mean_distances_across)
ax.set_xticklabels(['','Half\ndensity','Quarter\ndensity','Sphere','Sphere\nhalf','Sphere\nquarter','Disk','Disk\nhalf','Disk\nquarter'])
ax.set_ylabel('Normalized distance from baseline csd')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(111)
# ----> 3 ax.bar(np.arange(len(mean_distances_across)),mean_distances_across)
#       4 ax.set_xticklabels(['','Half\ndensity','Quarter\ndensity','Sphere','Sphere\nhalf','Sphere\nquarter','Disk','Disk\nhalf','Disk\nquarter'])
#       5 ax.set_ylabel('Normalized distance from baseline csd')
#
# File ~/conntilitEnv/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
# ...

# %%
distances = np.load('distances.npy')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(np.arange(len(distances)),distances.flatten())
ax.set_xticklabels(['','Half\ndensity','Quarter\ndensity','Sphere','Sphere\nhalf','Sphere\nquarter','Disk','Disk\nhalf','Disk\nquarter'])
ax.set_ylabel('Distance from baseline csd')
plt.tight_layout()
# Out:
# /nvme/tharayil/2275626/ipykernel_169923/173237882.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['','Half\ndensity','Quarter\ndensity','Sphere','Sphere\nhalf','Sphere\nquarter','Disk','Disk\nhalf','Disk\nquarter'])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
len(distances)
# Out:
# 8
