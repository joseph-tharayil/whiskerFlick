# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
p = pd.read_pickle('/gpfs/bbp.cscs.ch/project/proj83/scratch/home/tharayil/BlueRecording/examples/whiskerFlick/whiskerFlickSim/original/0/pkls/eegL5_TPC:A.pkl')
p1 = pd.read_pickle('original/fixed/a9f782a3-1f22-4384-a122-430bc6b2323c/5/pkls/eegL5_TPC:A.pkl')

# %%
p
# Out:
# electrode  Forelimb_EEG_Reciprocity       Testing
# 1975.0                 7.353108e-07  4.557608e-15
# 1975.1                 7.347077e-07  6.099269e-14
# 1975.2                 7.343868e-07  5.136251e-14
# 1975.3                 7.344720e-07  6.375082e-14
# 1975.4                 7.344516e-07  1.547247e-14
# ...                             ...           ...
# 2199.6                 7.397501e-07  4.733960e-14
# 2199.7                 7.397522e-07  2.974918e-14
# 2199.8                 7.388680e-07 -8.072477e-14
# 2199.9                 7.371906e-07  3.245113e-14
# 2200.0                 7.372914e-07 -2.652758e-14
#
# [2251 rows x 2 columns]

# %%
plt.figure()
plt.plot(p['Forelimb_EEG_Reciprocity'][2000:2200]-p['Forelimb_EEG_Reciprocity'][2000:2200].iloc[0])
plt.plot(p1['Forelimb_EEG_Reciprocity'][2000:2200]-p1['Forelimb_EEG_Reciprocity'][2000:2200].iloc[0])
# Out:
# /gpfs/bbp.cscs.ch/ssd/slurmTmpFS/tharayil/2510732/ipykernel_225732/3839921554.py:2: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   plt.plot(p['Forelimb_EEG_Reciprocity'][2000:2200]-p['Forelimb_EEG_Reciprocity'][2000:2200].iloc[0])
# /gpfs/bbp.cscs.ch/ssd/slurmTmpFS/tharayil/2510732/ipykernel_225732/3839921554.py:3: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   plt.plot(p1['Forelimb_EEG_Reciprocity'][2000:2200]-p1['Forelimb_EEG_Reciprocity'][2000:2200].iloc[0])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
